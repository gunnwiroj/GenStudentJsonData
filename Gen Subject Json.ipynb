# %%
import json as js

# %%
mgtpubtopic = ['1. สาธารณภัยจากโรคติดต่อ สัตว์มีพิษ และการจัดการ',
'2. ความหมาย ประเภท และที่มาของสาธารณภัย - นโยบายภาครัฐ และการจัดการโดยภาค รัฐ',
'3. สาธารณภัยจากธรรมชาติ และการจัดการ - สาธารณภัยจากการกระทําของมนุษย์ และ การจัดการ',
'4. สาธารณภัยอันเกิดจากอัคคีภัย และการจัดการ 1',
'5. สาธารณภัยอันเกิดจากอัคคีภัย และการจัดการ 2 - ฝึกปฏิบัติการดับเพลิงเบื้องต้น',
'6. พันธกิจของสภากาชาดไทยในการจัดการสาธารณภัย',
'7. สาธารณภัยจากการก่อการร้าย และการจัดการ',
'8. สาธารณภัยจากการคมนาคมทางบก และการจัดการ',
'9. ภาวะโรคระบาดกับการจัดการสาธารณภัย 1',
'10. ภาวะโรคระบาดกับการจัดการสาธารณภัย 2']

# %%
healthbeautopic = ['1. กลไกที่เกี่ยวข้องกับเมแทบอลิซึมภายในร่างกายเมื่อได้รับอาหารหลักและอาหารเสริม',
'2. ภาวะทุโภชนาการ วิธีการตรวจสอบภาวะโภชนาการ และสาเหตุของการเกิดโรคอ้วน รวม ถึงกลไกเชิงเมแทบอลิซึมของร่างกายในสภาวะขณะลดความอ้วน',
'3. สมดุลพลังงานของร่างกาย และการออกกําลังกายทั้งแบบที่ใช้ออกชิเจน (aerobic exercise) และไม่ใช้ออกซิเจน (anaerobic exercise) และวิธีการดูแลสุขภาพและกล้ามเนื้อ',
'4. ความสัมพันธ์์ของสภาวะทางจิตใจและสภาวะร่างกาย และการควบคุมระดับฮอร์โมนและสมอง',
'5. ส่วนประกอบของสมองที่เกี่ยวกับความจํา และกลไกหรือรูปแบบการจดจํา',
'6. ความสัมพันธ์ระหว่างสภาวะการลบ หรือเลือนความจํา กับการพักผ่อน และช่วงการนอนที่ สัมพันธ์กับคลื่นสมอง',
'7. กลไกการเกิดการแก่ชรา วิธีการสังเกต และป้องกัน รวมถึงการดูแลตัวเองเพื่อต้านชรา',
'8. ปัจจัยที่ทําให้เกิดความแก่ และสารเชิงชีวโมเลกุลที่เกี่ยวข้อง',
'9. ผลิตภัณฑ์ที่ต้านการแก่ชรา และกลไกการทํางานในร่างกายเพื่อชะลอความแก่',
'10. ผลิตภัณฑ์เสริมความงาม และกลไกการทํางานของผลิตภัณฑ์ดังกล่าว',
'11. เทคโนโลยีเสริมความงามในปัจจุบัน ทั้งเรื่องของ stem cell ซิลิโคน โบท็อกซ์ การร้อยไหม เป็นต้น และข้อควรระวัง']

# %%
ditigiphototopic = ['1. เนื้อหาเบื้องต้น การค้นหา ID ลักษณะของการเรียน การไปทริป และ การประเมินผล',
'2. ความรู้เกี่ยวกับการใช้งานกล้องและเลนส์',
'3. การจัดองค์ประกอบของภาพ',
'4. อุปกรณ์ถ่ายภาพ และฟังค์ชันต่างๆในกล้อง',
'5. เทคนิคการถ่ายภาพ และซอร์ฟแวร์ทางภาพ']

# %%
usefultopic = ['1. ธัญพืช และพืชอื่นที่ให้แป้ง',
'2. พืชที่ให้ความหวาน',
'3. พืชเศรษฐกิจ',
'4. ผักและพืชที่ให้นํ้ามันหอม',
'5. ผลไม้ และพืชที่ให้นํ้ามัน',
'6. สมุนไพรส่งเสริมสุขภาพ',
'7. ไม้ประดับ',
'8. เครื่องเทศ',
'9. พืชที่ใช้แต่งสี',
'10. พืชพิษ และพืชที่ทําให้ประสาทหลอน',
'11. สมุนไพรในสาธารณสุขมูลฐาน สมุนไพรในบัญชียาหลักแห่งชาติ และสมุนไพรที่พัฒนาเป็น ยา']

# %%
comprogtopic = ['1. Basic concepts in programming',
'2. Decisions in programming: flow of execution',
'3. Computer system',
'4. Computer network',
'5. Repetitions in programming: flow of execution',
'6. Arrays',
'7. Arrays & Function calls',
'8. Ethics and security']

# %%
import pandas as pd
file = pd.read_csv('Sci57.csv')
subject = pd.DataFrame()
subject['CourseId'] = file.CourseId
subject['CourseName'] = file.CourseName
subject = subject.drop_duplicates()

# %%
subject = subject[ subject.CourseId > 230000]

# %%
cleaned_data = []
for index, row in subject.iterrows():
    tmp = str(row['CourseId'])+':'+row['CourseName']
    cleaned_data.append(tmp)
#     print(tmp)

# %%
jsonobj = []
for i in cleaned_data:
    if i.split(':')[1].strip() == 'MGT PUB DISASTER':
        tmp = {
            "Subject_Id": i.split(':')[0].strip(),
            "Subject_Name": i.split(':')[1].strip(),
            "Detail":mgtpubtopic
            }
    elif i.split(':')[1].strip() == 'Health/beauty':
        tmp = {
            "Subject_Id": i.split(':')[0].strip(),
            "Subject_Name": i.split(':')[1].strip(),
            "Detail":healthbeautopic
            }
    elif i.split(':')[1].strip() == 'DIGITAL PHOTO':
        tmp = {
            "Subject_Id": i.split(':')[0].strip(),
            "Subject_Name": i.split(':')[1].strip(),
            "Detail":ditigiphototopic
            }
    elif i.split(':')[1].strip() == 'USEFUL PLANTS':
        tmp = {
            "Subject_Id": i.split(':')[0].strip(),
            "Subject_Name": i.split(':')[1].strip(),
            "Detail":usefultopic
            }
    elif i.split(':')[1].strip() == 'COMP PROG':
        tmp = {
            "Subject_Id": i.split(':')[0].strip(),
            "Subject_Name": i.split(':')[1].strip(),
            "Detail":comprogtopic
            }
    else :
        tmp = {
        "Subject_Id": i.split(':')[0].strip(),
        "Subject_Name": i.split(':')[1].strip(),
        "Detail":mock_detail_subject
        }
    jsonobj.append(tmp)

# %%
export_json = js.dumps(jsonobj, ensure_ascii=False)

# %%
export_json
# Out:
# '[{"Subject_Id": "2301113", "Subject_Name": "CALCULUS I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2302111", "Subject_Name": "GEN CHEM I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2302115", "Subject_Name": "GEN CHEM LAB I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2303101", "Subject_Name": "GEN BIO I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2303102", "Subject_Name": "GEN BIO LAB I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2304101", "Subject_Name": "GEN PHYS I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2304183", "Subject_Name": "GEN PHYS LAB I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "5500111", "Subject_Name": "EXP ENG I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2301114", "Subject_Name": "CALCULUS II", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2302112", "Subject_Name": "GEN CHEM II", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2302116", "Subject_Name": "GEN CHEM LAB II", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2304102", "Subject_Name": "GEN PHYS II", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2304184", "Subject_Name": "GEN PHYS LAB II", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2305101", "Subject_Name": "GEN BIO II", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2305102", "Subject_Name": "GEN BIO LAB II", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "3600205", "Subject_Name": "FAM HLTH CARE", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "5500112", "Subject_Name": "EXP ENG II", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2305107", "Subject_Name": "PLANT WORLD", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "3700114", "Subject_Name": "INTRO ENVI TOX", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2301170", "Subject_Name": "COMP PROG", "Detail": ["1. Basic concepts in programming", "2. Decisions in programming: flow of execution", "3. Computer system", "4. Computer network", "5. Repetitions in programming: flow of execution", "6. Arrays", "7. Arrays & Function calls", "8. Ethics and security"]}, {"Subject_Id": "2302271", "Subject_Name": "ORG CHEM I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2302273", "Subject_Name": "ORG CHEM LAB I", "Detail": ["1. pretium viverra suspendisse potenti", "2. volutpat est velit egestas dui id", "3. tempus urna et"]}, {"Subject_Id": "2303221", "S ...

# %%
file = open('SubjectJson.js','w')
file.write(export_json)
file.close()
